# %% [markdown]
# # ACI Create New User

# %% [markdown]
# This example shows how to create a new controller user.

# %% [markdown]
# We need to follow a workflow to gather the info needed for the POST request.
# Additionally, each input needs to be validated before posting, else we need to capture server responses and handle them correctly.

# %% [markdown]
# Things we should do before requesting input:
#  - Get all users from APIC.
#  - Get all roles from APIC.
#  - Get all security domains from APIC.
#
# When we take input, we can then present a list of roles and domains to select from, rather than allowing free-form typing.

# %%
# Set up all the modules we need.
import requests
import json
import pandas as pd
import os
import getpass
import sys

# %%
def get_info():
    # Read controller host/IP and auth credentials from a config file, if available. 
    # Test for config.py and import the variables.
    # Check if the variable is imported; if not, prompt for input.
    if os.path.isfile('./config.py'):
        from config import controller, username, password

    try:
        controller
    except NameError:
        controller = input("Controller Hostname/IP: ")

    try:
        username
    except NameError:
        username = input("APIC Username: ")
    
    try: 
        password 
    except NameError:
        password = getpass.getpass("APIC Password: ")

    return controller, username, password

# %%
controller, username, password = get_info()

# %%
print("Controller: " + controller)
print("Username: " + username)
#print("Password: " + password)
# Out:
# Controller: 10.18.188.101
# Username: api-andrew

# %%
# https://stackoverflow.com/questions/26310467/python-requests-keep-session-between-function
def session_init():
    # Set up the request and pass the authentication data as JSON
    s = requests.session()
    return s

# %%
def auth(controller, username, password):
    # Shhh! We don't want self-signed cert warnings.
    #requests.packages.urllib3.disable_warnings() 
    # Set up the POST request and pass the authentication data as JSON
    auth_class = "aaaLogin.json"
    auth_url = base_url + auth_class
    # Setup auth data as a dictionary 
    auth_data = {
        "aaaUser":{
            "attributes":{
                "name":username,
                "pwd":password
            }
        }
    }
    response = s.post(auth_url, json=auth_data, verify=False)
    return response

# %%
# Set up our URL
base_url = "https://" + str(controller) + "/api/"

#print(auth_url)
#print(auth_data)

# %%
s = session_init()
s
reply = auth(controller, username, password)
reply.status_code
# Out:
# /anaconda2/envs/aci/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 200

# %%
# We can use this to test the reponse code to determine if login was successful,
# and do something specific based on that (like execute a function).
#
# This can be expanded greatly to test against different codes (403, 404, 500, etc)
# if we wanted.

if reply.status_code != 200:
    print("Didn't authenticate.")
    print("HTTP Status: " + str(response))
else:
    print("All good")
# Out:
# All good

# %%
# Set up our user class URLs.
# We set up one for GETting data (inlcuding child objects)
# and one for POSTing data.

qstring = "?rsp-subtree=children"
# Construct the user post URL
user_class="node/mo/uni/userext.json"
post_user_url = base_url + user_class
get_user_url = base_url + user_class  + qstring
print(get_user_url)
print(post_user_url)
# Out:
# https://10.18.188.101/api/node/mo/uni/userext.json?rsp-subtree=children
# https://10.18.188.101/api/node/mo/uni/userext.json

# %%
def get_users():
    users = s.get(get_user_url, verify=False)
    users = users.json()
    print(json.dumps(users, indent=4, sort_keys=True))
    dn = users['imdata'][0]['aaaUserEp']['attributes']['dn']
    name_list = []
    firstname_list = []
    lastname_list = []
    status_list = []
    phone_list = []
    users_list = users['imdata'][0]['aaaUserEp']['children']
    for user in users_list:
        if "aaaUser" in user: 
            #print(user)
            rn = user['aaaUser']['attributes']['rn']
            name = user['aaaUser']['attributes']['name']  
            firstname = user['aaaUser']['attributes']['firstName']
            lastname = user['aaaUser']['attributes']['lastName']
            status = user['aaaUser']['attributes']['accountStatus']
            phone = user['aaaUser']['attributes']['phone']
            name_list.append(name)
            firstname_list.append(firstname)
            lastname_list.append(lastname)
            phone_list.append(phone)
            status_list.append(status)
    zlist = zip(status_list, name_list, firstname_list, lastname_list, phone_list, rn_list)
    df_input = list(zlist)
    df = pd.DataFrame(df_input, columns=("Status","User Name","First Name","Last Name","Phone","RN"))

# %%
def get_roles():
    roles = [1, 2, 3]
    return roles

# %%
def get_domains():
    domains = [1,2,3]
    return domains

# %%
def get_new_user():
    os.system('cls' if os.name == 'nt' else 'clear')
    prompt = input("Add New User? (y/N)")
    if prompt.lower() in ('n', 'N'):e
        sys.exit()
    elif prompt.lower() in ('y', 'Y'):
        get_user_input()
    else:
        get_new_user()

# %%
def input_pass():
    password1 = getpass.getpass("[Required] Password: ")
    password2 = getpass.getpass("[Required] Re-enter Password: ")
    if password1 != password2:
        print("Passwords are not the same. DO OVER!")
        print("(unless you wanna bug out now)")
        do_over = input("[D]o over, or [E]xit?")
        if do_over in ('D','d'):
            input_pass()
        sys.exit()
    return password1

# %%
def get_user_input():
    print("There's not much error checking here.") 
    print("You'll get a chance to re-enter, or you can just stop/restart the program.")
    print("Enter accepts [default] option.")
    print("--------------------")
    user = input("Username: ")
    print(" ")
    print("Password needs three of the following: ")
    print(" - lower case letter")
    print(" - upper case letter")
    print(" - number")
    print(" - symbol")
    print(" ")
    passwd = input_pass()
    firstname = input("[Optional] First Name: ")
    lastname = input("[Optional] Last Name: ")
    phone = input("[Optional] Phone: ")
    email = input("[Optional] Email: ")
    print("Enter security domains, with a [Y]es or [N]o: ")
    domain_all = input("Security Domain - All?  (y/n): ")
  
    if domain_all.lower() in ('y','Y','Yes','YES'):
        domain_all_priv = input("[R]ead or [W]rite: ")
    else:
        domain_all_priv = ""

    domain_common = input("Security Domain - Common? (y/n): ")
    if domain_common.lower() in ('y','Y','Yes','YES'):
        domain_common_priv = input("[R]ead or [W]rite: ")
    else:
        domain_common_priv = ""

    domain_mgmt = input("Security Domain - Mgmt? (y/n): ")
    if domain_mgmt.lower() in ('y','Y','Yes','YES'):
        domain_mgmt_priv = input("[R]ead or [W]rite: ")
    else:
        domain_mgmt_priv = ""

    expires = input("Expires? [y/n]")
    activate = input("Activate User? [y/n]")
    print("----------------------------------------")
    print("How does this look?")
    print("Username: " + str(user))
    print("Password: ***** ")
    print("First Name: " + str(firstname))
    print("Last Name: " + str(lastname))
    print("Email: " + str(phone))
    print("Email: " + str(email))
    print("Security Domain - All: " + str(domain_all))
    print("Security Domain - All: " + str(domain_all_priv))
    print("Security Domain - Common: " + str(domain_common))
    print("Security Domain - Common: " + str(domain_common_priv))
    print("Security Domain - Mgmt: " + str(domain_mgmt))
    print("Security Domain - Mgmt: " + str(domain_mgmt_priv))
    print("Expires: " + str(expires))
    print("Active: " + str(activate))
    is_good = input("[G]o go gadget FORM POST!" + "\n" + "[D]o over. *sad trombone")
    if is_good in ('G','g'):
        print("An API POST happens here.")
    elif is_good in ('D','d'):
        
    return user, passwd, firstname, lastname, phone, email, domain_all, domain_all_priv, domain_common, domain_common_priv, domain_mgmt, domain_mgmt_priv, expires, activate

# %%
get_roles()
# Out:
# [1, 2, 3]

# %%
get_domains()
# Out:
# [1, 2, 3]

# %%
get_users()
# Out:
# /anaconda2/envs/aci/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {
#     "imdata": [
#         {
#             "aaaUserEp": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/userext",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-17T13:52:59.962-05:00",
#                     "monPolDn": "uni/fabric/monfab-default",
#                     "name": "",
#                     "nameAlias": "",
#                     "newSubscr": "yes",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "pwdStrengthCheck": "yes",
#                     "status": "",
#                     "uid": "0"
#                 },
#                 "children": [
#                     {
#                         "aaaUserConf": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "deleteNonPresent",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "uconfroot",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "userconf",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaPingEp": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "pingCheck": "true",
#                                 "retries": "1",
#                                 "rn": "pingext",
#                                 "status": "",
#                                 "timeout": "5",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaLoginDomain": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "Special login domain to allow fallback to local authentication if customer locks themselves out by changing the DefaultAuth and ConsoleAuth realms",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "fallback",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "logindomain-fallback",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "pkiEp": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "pkiext",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaPwdProfile": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "changeCount": "2",
#                                 "changeDuringInterval": "enable",
#                                 "changeInterval": "48",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "expirationWarnTime": "15",
#                                 "extMngdBy": "",
#                                 "historyCount": "5",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "noChangeInterval": "24",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "pwdprofile",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaLdapEp": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "attribute": "CiscoAVPair",
#                                 "basedn": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "filter": "sAMAccountName=$userid",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "retries": "1",
#                                 "rn": "ldapext",
#                                 "status": "",
#                                 "timeout": "30",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaSamlEp": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "retries": "1",
#                                 "rn": "samlext",
#                                 "status": "",
#                                 "timeout": "5",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaPreLoginBanner": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "guiMessage": "",
#                                 "guiTextMessage": "COAST LAB",
#                                 "lcOwn": "local",
#                                 "message": "Application Policy Infrastructure Controller",
#                                 "modTs": "2018-11-27T16:46:26.249-05:00",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "preloginbanner",
#                                 "status": "",
#                                 "switchMessage": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaKafkaEp": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-29T10:55:56.208-05:00",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "retries": "1",
#                                 "rn": "kafkaext",
#                                 "status": "",
#                                 "timeout": "5",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "vmm-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "vmm-connectivity,vmm-ep,vmm-policy,vmm-protocol-ops,vmm-security",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-vmm-admin",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "access-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "access-connectivity-l1,access-connectivity-l2,access-connectivity-l3,access-connectivity-mgmt,access-connectivity-util,access-equipment,access-protocol-l1,access-protocol-l2,access-protocol-l3,access-protocol-mgmt,access-protocol-ops,access-protocol-util,access-qos",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-access-admin",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "tenant-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "aaa,access-connectivity-l1,access-connectivity-l2,access-connectivity-l3,access-connectivity-mgmt,access-connectivity-util,access-equipment,access-protocol-l1,access-protocol-l2,access-protocol-l3,access-protocol-mgmt,access-protocol-ops,access-protocol-util,access-qos,fabric-connectivity-l1,fabric-connectivity-l2,fabric-connectivity-l3,fabric-connectivity-mgmt,fabric-connectivity-util,fabric-equipment,fabric-protocol-l1,fabric-protocol-l2,fabric-protocol-l3,fabric-protocol-mgmt,fabric-protocol-ops,fabric-protocol-util,nw-svc-device,nw-svc-devshare,nw-svc-policy,ops,tenant-connectivity-l1,tenant-connectivity-l2,tenant-connectivity-l3,tenant-connectivity-mgmt,tenant-connectivity-util,tenant-epg,tenant-ext-connectivity-l1,tenant-ext-connectivity-l2,tenant-ext-connectivity-l3,tenant-ext-connectivity-mgmt,tenant-ext-connectivity-util,tenant-ext-protocol-l1,tenant-ext-protocol-l2,tenant-ext-protocol-l3,tenant-ext-protocol-mgmt,tenant-ext-protocol-util,tenant-network-profile,tenant-protocol-l1,tenant-protocol-l2,tenant-protocol-l3,tenant-protocol-mgmt,tenant-protocol-ops,tenant-protocol-util,tenant-qos,tenant-security,vmm-connectivity,vmm-ep,vmm-policy,vmm-protocol-ops,vmm-security",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-tenant-admin",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "ops",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "ops",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-ops",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "tenant-ext-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "tenant-connectivity-l1,tenant-connectivity-l2,tenant-connectivity-l3,tenant-connectivity-mgmt,tenant-connectivity-util,tenant-epg,tenant-ext-connectivity-l1,tenant-ext-connectivity-l2,tenant-ext-connectivity-l3,tenant-ext-connectivity-mgmt,tenant-ext-connectivity-util,tenant-ext-protocol-l1,tenant-ext-protocol-l2,tenant-ext-protocol-l3,tenant-ext-protocol-mgmt,tenant-ext-protocol-util,tenant-network-profile,tenant-protocol-l1,tenant-protocol-l2,tenant-protocol-l3,tenant-protocol-mgmt,tenant-protocol-ops,tenant-protocol-util,tenant-qos,tenant-security",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-tenant-ext-admin",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "nw-svc-params",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "nw-svc-params",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-nw-svc-params",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "read-all",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "access-connectivity-l1,access-connectivity-l2,access-connectivity-l3,access-connectivity-mgmt,access-connectivity-util,access-equipment,access-protocol-l1,access-protocol-l2,access-protocol-l3,access-protocol-mgmt,access-protocol-ops,access-protocol-util,access-qos,fabric-connectivity-l1,fabric-connectivity-l2,fabric-connectivity-l3,fabric-connectivity-mgmt,fabric-connectivity-util,fabric-equipment,fabric-protocol-l1,fabric-protocol-l2,fabric-protocol-l3,fabric-protocol-mgmt,fabric-protocol-ops,fabric-protocol-util,nw-svc-device,nw-svc-devshare,nw-svc-policy,ops,tenant-connectivity-l1,tenant-connectivity-l2,tenant-connectivity-l3,tenant-connectivity-mgmt,tenant-connectivity-util,tenant-epg,tenant-ext-connectivity-l1,tenant-ext-connectivity-l2,tenant-ext-connectivity-l3,tenant-ext-connectivity-mgmt,tenant-ext-connectivity-util,tenant-ext-protocol-l1,tenant-ext-protocol-l2,tenant-ext-protocol-l3,tenant-ext-protocol-mgmt,tenant-ext-protocol-util,tenant-network-profile,tenant-protocol-l1,tenant-protocol-l2,tenant-protocol-l3,tenant-protocol-mgmt,tenant-protocol-ops,tenant-protocol-util,tenant-qos,tenant-security,vmm-connectivity,vmm-ep,vmm-policy,vmm-protocol-ops,vmm-security",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-read-all",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "admin",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-admin",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "nw-svc-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "nw-svc-device,nw-svc-devshare,nw-svc-policy",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-nw-svc-admin",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "aaa",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "aaa",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-aaa",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFactoryRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "fabric-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "fabric-connectivity-l1,fabric-connectivity-l2,fabric-connectivity-l3,fabric-connectivity-mgmt,fabric-connectivity-util,fabric-equipment,fabric-protocol-l1,fabric-protocol-l2,fabric-protocol-l3,fabric-protocol-mgmt,fabric-protocol-ops,fabric-protocol-util",
#                                 "resetToFactory": "no",
#                                 "rn": "factoryrole-fabric-admin",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaFabricSec": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "fipsMode": "disable",
#                                 "fipsReboot": "no",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "fabricsec",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:13.424-05:00",
#                                 "name": "Cisco_EnhancedEndpointTracker",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "admin",
#                                 "resetToFactory": "no",
#                                 "rn": "role-Cisco_EnhancedEndpointTracker",
#                                 "roleIsBuiltin": "no",
#                                 "status": "",
#                                 "uid": "15374"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:13.424-05:00",
#                                 "name": "Cisco_ContractViewer",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "tenant-epg,tenant-network-profile,tenant-security",
#                                 "resetToFactory": "no",
#                                 "rn": "role-Cisco_ContractViewer",
#                                 "roleIsBuiltin": "no",
#                                 "status": "",
#                                 "uid": "15374"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "aaa",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "aaa",
#                                 "resetToFactory": "no",
#                                 "rn": "role-aaa",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "nw-svc-params",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "nw-svc-params",
#                                 "resetToFactory": "no",
#                                 "rn": "role-nw-svc-params",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "admin",
#                                 "resetToFactory": "no",
#                                 "rn": "role-admin",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "ops",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "ops",
#                                 "resetToFactory": "no",
#                                 "rn": "role-ops",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "vmm-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "vmm-connectivity,vmm-ep,vmm-policy,vmm-protocol-ops,vmm-security",
#                                 "resetToFactory": "no",
#                                 "rn": "role-vmm-admin",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "tenant-ext-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "tenant-connectivity-l1,tenant-connectivity-l2,tenant-connectivity-l3,tenant-connectivity-mgmt,tenant-connectivity-util,tenant-epg,tenant-ext-connectivity-l1,tenant-ext-connectivity-l2,tenant-ext-connectivity-l3,tenant-ext-connectivity-mgmt,tenant-ext-connectivity-util,tenant-ext-protocol-l1,tenant-ext-protocol-l2,tenant-ext-protocol-l3,tenant-ext-protocol-mgmt,tenant-ext-protocol-util,tenant-network-profile,tenant-protocol-l1,tenant-protocol-l2,tenant-protocol-l3,tenant-protocol-mgmt,tenant-protocol-ops,tenant-protocol-util,tenant-qos,tenant-security",
#                                 "resetToFactory": "no",
#                                 "rn": "role-tenant-ext-admin",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "access-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "access-connectivity-l1,access-connectivity-l2,access-connectivity-l3,access-connectivity-mgmt,access-connectivity-util,access-equipment,access-protocol-l1,access-protocol-l2,access-protocol-l3,access-protocol-mgmt,access-protocol-ops,access-protocol-util,access-qos",
#                                 "resetToFactory": "no",
#                                 "rn": "role-access-admin",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "fabric-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "fabric-connectivity-l1,fabric-connectivity-l2,fabric-connectivity-l3,fabric-connectivity-mgmt,fabric-connectivity-util,fabric-equipment,fabric-protocol-l1,fabric-protocol-l2,fabric-protocol-l3,fabric-protocol-mgmt,fabric-protocol-ops,fabric-protocol-util",
#                                 "resetToFactory": "no",
#                                 "rn": "role-fabric-admin",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:13.424-05:00",
#                                 "name": "Cisco_APICPostman",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "admin",
#                                 "resetToFactory": "no",
#                                 "rn": "role-Cisco_APICPostman",
#                                 "roleIsBuiltin": "no",
#                                 "status": "",
#                                 "uid": "15374"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "nw-svc-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "nw-svc-device,nw-svc-devshare,nw-svc-policy",
#                                 "resetToFactory": "no",
#                                 "rn": "role-nw-svc-admin",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "tenant-admin",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "aaa,access-connectivity-l1,access-connectivity-l2,access-connectivity-l3,access-connectivity-mgmt,access-connectivity-util,access-equipment,access-protocol-l1,access-protocol-l2,access-protocol-l3,access-protocol-mgmt,access-protocol-ops,access-protocol-util,access-qos,fabric-connectivity-l1,fabric-connectivity-l2,fabric-connectivity-l3,fabric-connectivity-mgmt,fabric-connectivity-util,fabric-equipment,fabric-protocol-l1,fabric-protocol-l2,fabric-protocol-l3,fabric-protocol-mgmt,fabric-protocol-ops,fabric-protocol-util,nw-svc-device,nw-svc-devshare,nw-svc-policy,ops,tenant-connectivity-l1,tenant-connectivity-l2,tenant-connectivity-l3,tenant-connectivity-mgmt,tenant-connectivity-util,tenant-epg,tenant-ext-connectivity-l1,tenant-ext-connectivity-l2,tenant-ext-connectivity-l3,tenant-ext-connectivity-mgmt,tenant-ext-connectivity-util,tenant-ext-protocol-l1,tenant-ext-protocol-l2,tenant-ext-protocol-l3,tenant-ext-protocol-mgmt,tenant-ext-protocol-util,tenant-network-profile,tenant-protocol-l1,tenant-protocol-l2,tenant-protocol-l3,tenant-protocol-mgmt,tenant-protocol-ops,tenant-protocol-util,tenant-qos,tenant-security,vmm-connectivity,vmm-ep,vmm-policy,vmm-protocol-ops,vmm-security",
#                                 "resetToFactory": "no",
#                                 "rn": "role-tenant-admin",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRole": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "read-all",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "priv": "access-connectivity-l1,access-connectivity-l2,access-connectivity-l3,access-connectivity-mgmt,access-connectivity-util,access-equipment,access-protocol-l1,access-protocol-l2,access-protocol-l3,access-protocol-mgmt,access-protocol-ops,access-protocol-util,access-qos,fabric-connectivity-l1,fabric-connectivity-l2,fabric-connectivity-l3,fabric-connectivity-mgmt,fabric-connectivity-util,fabric-equipment,fabric-protocol-l1,fabric-protocol-l2,fabric-protocol-l3,fabric-protocol-mgmt,fabric-protocol-ops,fabric-protocol-util,nw-svc-device,nw-svc-devshare,nw-svc-policy,ops,tenant-connectivity-l1,tenant-connectivity-l2,tenant-connectivity-l3,tenant-connectivity-mgmt,tenant-connectivity-util,tenant-epg,tenant-ext-connectivity-l1,tenant-ext-connectivity-l2,tenant-ext-connectivity-l3,tenant-ext-connectivity-mgmt,tenant-ext-connectivity-util,tenant-ext-protocol-l1,tenant-ext-protocol-l2,tenant-ext-protocol-l3,tenant-ext-protocol-mgmt,tenant-ext-protocol-util,tenant-network-profile,tenant-protocol-l1,tenant-protocol-l2,tenant-protocol-l3,tenant-protocol-mgmt,tenant-protocol-ops,tenant-protocol-util,tenant-qos,tenant-security,vmm-connectivity,vmm-ep,vmm-policy,vmm-protocol-ops,vmm-security",
#                                 "resetToFactory": "no",
#                                 "rn": "role-read-all",
#                                 "roleIsBuiltin": "yes",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaAuthRealm": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "defRolePolicy": "no-login",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "authrealm",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "opflexODevEp": {
#                             "attributes": {
#                                 "childAction": "deleteNonPresent",
#                                 "descr": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "odevpkiext",
#                                 "status": ""
#                             }
#                         }
#                     },
#                     {
#                         "aaaDomain": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "mgmt",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "domain-mgmt",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaDomain": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "all",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "domain-all",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaDomain": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "name": "common",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "domain-common",
#                                 "status": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRadiusEp": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "retries": "1",
#                                 "rn": "radiusext",
#                                 "status": "",
# ...
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "phone": "",
#                                 "pwdLifeTime": "no-password-expire",
#                                 "pwdUpdateRequired": "no",
#                                 "rbacString": "",
#                                 "rn": "user-stcorry",
#                                 "status": "",
#                                 "uid": "15374",
#                                 "unixUserId": "11296"
#                             }
#                         }
#                     },
#                     {
#                         "aaaUser": {
#                             "attributes": {
#                                 "accountStatus": "active",
#                                 "annotation": "",
#                                 "certAttribute": "",
#                                 "childAction": "",
#                                 "clearPwdHistory": "no",
#                                 "descr": "",
#                                 "email": "",
#                                 "expiration": "never",
#                                 "expires": "no",
#                                 "extMngdBy": "",
#                                 "firstName": "Andrew",
#                                 "lastName": "The API User",
#                                 "lcOwn": "local",
#                                 "modTs": "2019-05-21T13:29:56.934-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "api-andrew",
#                                 "nameAlias": "",
#                                 "otpenable": "no",
#                                 "otpenf": "yes",
#                                 "otpkey": "DISABLEDDISABLED",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "phone": "",
#                                 "pwdLifeTime": "no-password-expire",
#                                 "pwdUpdateRequired": "no",
#                                 "rbacString": "",
#                                 "rn": "user-api-andrew",
#                                 "status": "",
#                                 "uid": "13295",
#                                 "unixUserId": "15654"
#                             }
#                         }
#                     },
#                     {
#                         "aaaUser": {
#                             "attributes": {
#                                 "accountStatus": "active",
#                                 "annotation": "",
#                                 "certAttribute": "",
#                                 "childAction": "",
#                                 "clearPwdHistory": "no",
#                                 "descr": "Created by Andrew for when he needs to show functioning code over a webex and doesnt want to give out passwords",
#                                 "email": "",
#                                 "expiration": "never",
#                                 "expires": "no",
#                                 "extMngdBy": "",
#                                 "firstName": "Example",
#                                 "lastName": "User",
#                                 "lcOwn": "local",
#                                 "modTs": "2019-02-13T11:25:57.592-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "api",
#                                 "nameAlias": "",
#                                 "otpenable": "no",
#                                 "otpenf": "yes",
#                                 "otpkey": "DISABLEDDISABLED",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "phone": "256-512-1024",
#                                 "pwdLifeTime": "no-password-expire",
#                                 "pwdUpdateRequired": "no",
#                                 "rbacString": "",
#                                 "rn": "user-api",
#                                 "status": "",
#                                 "uid": "15374",
#                                 "unixUserId": "14941"
#                             }
#                         }
#                     },
#                     {
#                         "aaaUser": {
#                             "attributes": {
#                                 "accountStatus": "active",
#                                 "annotation": "",
#                                 "certAttribute": "",
#                                 "childAction": "",
#                                 "clearPwdHistory": "no",
#                                 "descr": "TD team",
#                                 "email": "slym@cisco.com",
#                                 "expiration": "never",
#                                 "expires": "no",
#                                 "extMngdBy": "",
#                                 "firstName": "Steven",
#                                 "lastName": "Lym",
#                                 "lcOwn": "local",
#                                 "modTs": "2019-04-19T20:07:38.559-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "slym",
#                                 "nameAlias": "",
#                                 "otpenable": "no",
#                                 "otpenf": "yes",
#                                 "otpkey": "DISABLEDDISABLED",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "phone": "",
#                                 "pwdLifeTime": "no-password-expire",
#                                 "pwdUpdateRequired": "no",
#                                 "rbacString": "",
#                                 "rn": "user-slym",
#                                 "status": "",
#                                 "uid": "15374",
#                                 "unixUserId": "8274"
#                             }
#                         }
#                     },
#                     {
#                         "aaaUser": {
#                             "attributes": {
#                                 "accountStatus": "active",
#                                 "annotation": "",
#                                 "certAttribute": "",
#                                 "childAction": "",
#                                 "clearPwdHistory": "no",
#                                 "descr": "",
#                                 "email": "",
#                                 "expiration": "never",
#                                 "expires": "no",
#                                 "extMngdBy": "",
#                                 "firstName": "",
#                                 "lastName": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:23.629-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "cspc",
#                                 "nameAlias": "",
#                                 "otpenable": "no",
#                                 "otpenf": "yes",
#                                 "otpkey": "DISABLEDDISABLED",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "phone": "",
#                                 "pwdLifeTime": "no-password-expire",
#                                 "pwdUpdateRequired": "no",
#                                 "rbacString": "",
#                                 "rn": "user-cspc",
#                                 "status": "",
#                                 "uid": "15374",
#                                 "unixUserId": "10783"
#                             }
#                         }
#                     },
#                     {
#                         "aaaUser": {
#                             "attributes": {
#                                 "accountStatus": "active",
#                                 "annotation": "",
#                                 "certAttribute": "",
#                                 "childAction": "",
#                                 "clearPwdHistory": "no",
#                                 "descr": "",
#                                 "email": "",
#                                 "expiration": "never",
#                                 "expires": "no",
#                                 "extMngdBy": "",
#                                 "firstName": "",
#                                 "lastName": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:23.629-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "admin",
#                                 "nameAlias": "",
#                                 "otpenable": "no",
#                                 "otpenf": "yes",
#                                 "otpkey": "DISABLEDDISABLED",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "phone": "",
#                                 "pwdLifeTime": "no-password-expire",
#                                 "pwdUpdateRequired": "no",
#                                 "rbacString": "",
#                                 "rn": "user-admin",
#                                 "status": "",
#                                 "uid": "0",
#                                 "unixUserId": "15374"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRsaEp": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "descr": "",
#                                 "extMngdBy": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "retries": "1",
#                                 "rn": "rsaext",
#                                 "status": "",
#                                 "timeout": "5",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRtUserEp": {
#                             "attributes": {
#                                 "childAction": "deleteNonPresent",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:31:50.067-05:00",
#                                 "rn": "rtuserEp-[secRelnHolder]",
#                                 "status": "",
#                                 "tCl": "aaaSecRelnHolder",
#                                 "tDn": "secRelnHolder"
#                             }
#                         }
#                     },
#                     {
#                         "aaaRtToUserEp": {
#                             "attributes": {
#                                 "childAction": "deleteNonPresent",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "rn": "rttoUserEp",
#                                 "status": "",
#                                 "tCl": "aaaUserEp",
#                                 "tDn": "uni/userext"
#                             }
#                         }
#                     },
#                     {
#                         "aaaAppUser": {
#                             "attributes": {
#                                 "childAction": "deleteNonPresent",
#                                 "ciscoAvPair": "all//admin|",
#                                 "descr": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2019-04-09T21:08:15.755-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "Cisco_NAEPE",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "appuser-Cisco_NAEPE",
#                                 "status": ""
#                             }
#                         }
#                     },
#                     {
#                         "aaaAppUser": {
#                             "attributes": {
#                                 "childAction": "deleteNonPresent",
#                                 "ciscoAvPair": "all/admin|/",
#                                 "descr": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2019-04-10T10:17:34.651-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "Cisco_NIR",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "appuser-Cisco_NIR",
#                                 "status": ""
#                             }
#                         }
#                     },
#                     {
#                         "aaaAppUser": {
#                             "attributes": {
#                                 "childAction": "deleteNonPresent",
#                                 "ciscoAvPair": "all/admin|/",
#                                 "descr": "",
#                                 "lcOwn": "local",
#                                 "modTs": "2019-05-04T10:41:29.978-05:00",
#                                 "monPolDn": "uni/fabric/monfab-default",
#                                 "name": "Cisco_ExternalSwitch",
#                                 "nameAlias": "",
#                                 "ownerKey": "",
#                                 "ownerTag": "",
#                                 "rn": "appuser-Cisco_ExternalSwitch",
#                                 "status": ""
#                             }
#                         }
#                     },
#                     {
#                         "aaaRsToUserEp": {
#                             "attributes": {
#                                 "childAction": "deleteNonPresent",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-16T16:30:45.431-05:00",
#                                 "rType": "mo",
#                                 "rn": "rstoUserEp",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "aaaUserEp",
#                                 "tDn": "uni/userext",
#                                 "tType": "mo"
#                             }
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "totalCount": "1"
# }
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2ba5a99356df> in <module>
# ----> 1 get_users()
#
# <ipython-input-11-47985b8dc7da> in get_users()
#      24             phone_list.append(phone)
#      25             status_list.append(status)
# ---> 26     zlist = zip(status_list, name_list, firstname_list, lastname_list, phone_list, rn_list)
#      27     df_input = list(zlist)
#      28     df = pd.DataFrame(df_input, columns=("Status","User Name","First Name","Last Name","Phone","RN"))
#
# NameError: name 'rn_list' is not defined

# %%
# Prompt for user info
prompt = input("Add New User? (y/N)")
# Out:
# Add New User? (y/N)y

# %%
if prompt.lower() not in ('y', 'Y'):
    sys.exit()

# %%
get_user_input()
# Out:
# There's not much error checking here.
# You'll get a chance to re-enter, or you can just stop/restart the program.
# Enter accepts [default] option.
#
# Username: schmuck
#
# Password needs three of the following:
#  - lower case letter
#  - upper case letter
#  - number
#  - symbol
#
# [Required] Password: ········
# [Required] Re-enter Password: ········
# [Optional] First Name: asdf
# [Optional] Last Name: qwer
# [Optional] Phone: asdf
# [Optional] Email:
# Enter security domains, with a [Y]es or [N]o:
# Security Domain - All?  (y/n): y
# [R]ead or [W]rite: w
# Security Domain - Common? (y/n): n
# Security Domain - Mgmt? (y/n): n
# Expires? [y/n]n
# Activate User? [y/n]y
# ('schmuck',
#  'yadda',
#  'asdf',
#  'qwer',
#  'asdf',
#  '',
#  'y',
#  'w',
#  'n',
#  '',
#  'n',
#  '',
#  'n',
#  'y')

# %%
print("Username: " + str(user))
print("Password: ***** ")
print("First Name: " + str(firstname))
print("Last Name: " + str(lastname))
print("Email: " + str(phone))
print("Email: " + str(email))
print("Security Domain - All: " + str(domain_all))
print("Security Domain - All: " + str(domain_all_priv))
print("Security Domain - Common: " + str(domain_common))
print("Security Domain - Common: " + str(domain_common_priv))
print("Security Domain - Mgmt: " + str(domain_mgmt))
print("Security Domain - Mgmt: " + str(domain_mgmt_priv))
print("Expires: " + str(expires))
print("Active: " + str(activate))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2f4937c31014> in <module>
# ----> 1 print("Username: " + str(user))
#       2 print("Password: ***** ")
#       3 print("First Name: " + str(firstname))
#       4 print("Last Name: " + str(lastname))
#       5 print("Email: " + str(phone))
#
# NameError: name 'user' is not defined

# %%
userext = "uni/userext.json"

# %% [markdown]
# ## User POST Data
# ```
# {
#             "aaaUser": {
#                 "attributes": {
#                     "name": user,
#                     "firstName": firstname,
#                     "lastName": lastname,
#                     "phone": phone,
#                     "email": email,
#                 },
#                 "children": [{
#                     "aaaUserCert": {
#                         "attributes": {
#                             "name": "userabc.crt",
#                             "data": "-----BEGIN CERTIFICATE-----\nMIICjjCCAfegAwIBAgIJAMQnbE <snipped content> ==\n-----END CERTIFICATE-----",
#                         },
#                         "children": []
#                     },
#                     "aaaUserDomain": {
#                         "attributes": {
#                             "name": "all",
#                         },
#                         "children": [{
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "aaa",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "access-admin",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "admin",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "fabric-admin",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "nw-svc-admin",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "ops",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "read-all",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "tenant-admin",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "tenant-ext-admin",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }, {
#                             "aaaUserRole": {
#                                 "attributes": {
#                                     "name": "vmm-admin",
#                                     "privType": "writePriv",
#                                 },
#                                 "children": []
#                             }
#                         }]
#                     }
#                 }]
#             }
#         }
# ```
