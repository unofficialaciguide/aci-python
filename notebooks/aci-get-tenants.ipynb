# %% [markdown]
# # Unofficial ACI Guide
#
# ## Python 3 - Get Tenants Example

# %% [markdown]
# This is a simple Python example demonstrating how to list all tenants in a fabric.
# No Cisco ACI-related toolkits, SDKs, or bindings were harmed in the creation of this example.

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# Enter your controller hostname/IP and user credentials below.
# You probably don't want to do this while someone watches over your shoulder.

# %%
# Variables to construct our URLs.
# Configure username, password, and controller.
# See aci-auth.ipynb notebook for examples on getting user/pass
# inline, from config files, and from input prompts.

from config import controller, username, password
base_url = "https://" + str(controller) + "/api/"
auth_bit = "aaaLogin.json"

auth_url = base_url + auth_bit

# %%
# JSON auth data 
auth_data = {
  "aaaUser":{
    "attributes":{
      "name":username,
      "pwd":password
    }
  }
}

# %% [markdown]
# ## Construct the Request

# %%
# We use verify=False to allow self-signed certs. 
# The disable_warnings() line prevents warning messages.
requests.packages.urllib3.disable_warnings() 
s = requests.session()
s.post(auth_url, json=auth_data, verify=False)
# Out:
# <Response [200]>

# %%
# Construct the tenant URL
tenant_class="node/class/fvTenant.json"
#tenant_url = base_url + tenant_class
tenant_url = base_url + tenant_class
tenant_url

# %%
tenants = s.get(tenant_url, verify=False)
s_out = tenants.json()
print(json.dumps(s_out, indent=4, sort_keys=True))
# Out:
# {
#     "imdata": [
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-infra",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-16T16:30:51.657-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "infra",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "0"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC3",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-17T15:11:22.648-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "EPIC3",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-andrew",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-12-19T12:08:02.718-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "andrew",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-17T15:11:23.412-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "EPIC",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-mgmt",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-16T16:30:50.661-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "mgmt",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "0"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-JW_Tenant",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-17T15:11:22.374-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "JW_Tenant",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-J_Tenant",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-17T15:11:15.307-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "J_Tenant",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-common",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-16T16:30:45.214-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "common",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "0"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC4",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-12-17T15:00:20.553-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "EPIC4",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-COAST",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-12-14T12:43:33.898-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "COAST",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         },
#         {
#             "fvTenant": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC2",
#                     "extMngdBy": "",
#                     "lcOwn": "local",
#                     "modTs": "2018-11-17T15:11:22.310-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "EPIC2",
#                     "nameAlias": "",
#                     "ownerKey": "",
#                     "ownerTag": "",
#                     "status": "",
#                     "uid": "15374"
#                 }
#             }
#         }
#     ],
#     "totalCount": "11"
# }

# %%
# Let's get all our tenants now.
# Stasrt with an empty list.
tenant_list = []

# The imdata dictionary has a single list value, which we'll extract into "tn_out_list"
tn_out_list = s_out['imdata']
for tenant in tn_out_list:
    # The elements of the list are individual dictionaries 
    # and are no longer elements in a list.
    # object = the list index, and we'll read the value
    # which is a key to a disctionary which itself is a key
    # to another dictionary, ad naseaum.
    
    # Uncomment the following print statement if you want to see the individual dictionaries.
    # print(tenant)
    
    dn = tenant['fvTenant']['attributes']['dn']
    split_dn = dn.split("/")
    tenant_list.append(split_dn[1])
    
print("Tenants: ")
[print(" " + t) for t in tenant_list]
# Out:
# Tenants:
#  tn-infra
#  tn-EPIC3
#  tn-andrew
#  tn-EPIC
#  tn-mgmt
#  tn-JW_Tenant
#  tn-J_Tenant
#  tn-common
#  tn-EPIC4
#  tn-COAST
#  tn-EPIC2
# [None, None, None, None, None, None, None, None, None, None, None]
