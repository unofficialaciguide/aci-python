# %% [markdown]
# # Unofficial ACI Guide
#
# ## Python 3 - Get All Tenant Endpoint Groups and their Endpoints Example

# %% [markdown]
# This is a simple Python example demonstrating how to get tenants, endpoint groups, and endpoints.
# No Cisco ACI-related toolkits, SDKs, or bindings were harmed in the creation of this example.

# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
# Variables to construct our URLs.
# Configure username, password, and controller in config.py.
# See aci-auth.ipynb notebook for examples on getting user/pass
# inline, from config files, and from input prompts.

from config import controller, username, password
base_url = "https://" + str(controller) + "/api/"
auth_bit = "aaaLogin.json"

auth_url = base_url + auth_bit

# %%
# JSON auth data 
auth_data = {
  "aaaUser":{
    "attributes":{
      "name":username,
      "pwd":password
    }
  }
}

# %% [markdown]
# ## Construct the Request

# %%
# We use verify=False to allow self-signed certs. 
# The disable_warnings() line prevents warning messages.
requests.packages.urllib3.disable_warnings() 
s = requests.session()
s.post(auth_url, json=auth_data, verify=False)
# Out:
# <Response [200]>

# %% [markdown]
# ### Get all EPGs

# %%
c_string = "?rsp-subtree=children"
epg_path="node/class/fvAEPg.json"
epg_url = base_url + epg_path + c_string
epg_url
# Out:
# 'https://10.18.188.101/api/node/class/fvAEPg.json?rsp-subtree=children'

# %%
# Set the value of "epg_response" to the output of a GET request to the EPG URL.
# Then take that output and turn it into a Python object (a dictionary).
epg_response = s.get(epg_url, verify=False)
epg_json = epg_response.json()

# %%
print(json.dumps(epg_json, indent=4, sort_keys=True))
# The response is a JSON dictionary with two keys: imdata and totalCount.
# The value for imdata is a list of objects, while the value of totalCount is a count of those objects. 
# Thd totalCount can be used to cross-check any data handling so that you don't 'lose' objects 
# during any filtering/processing/handling.
# Out:
# {
#     "imdata": [
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "Digitial Signing Server",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-Digital_SS",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.786-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "Digital_SS",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "32784",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-DigitalSigningServer",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-DigitalSigningServer",
#                                 "tRn": "brc-DigitalSigningServer",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "DigitalSigningServer",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-CacheDB",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CacheDB",
#                                 "tRn": "brc-CacheDB",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CacheDB",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:22.505-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-Digital_SS_BD",
#                                 "tRn": "BD-Digital_SS_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "Digital_SS_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "EPIC CareLink Web",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-CareLinkWeb",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.786-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "CareLinkWeb",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "49168",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-EpicCare_Link",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-EpicCare_Link",
#                                 "tRn": "brc-EpicCare_Link",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "EpicCare_Link",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-CacheDB",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CacheDB",
#                                 "tRn": "brc-CacheDB",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CacheDB",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:22.505-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-CareLinkWeb_BD",
#                                 "tRn": "BD-CareLinkWeb_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "CareLinkWeb_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-CommProxy",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.412-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "CommProxy",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "32780",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-CommProxy",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CommProxy",
#                                 "tRn": "brc-CommProxy",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CommProxy",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-FullClient",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-FullClient",
#                                 "tRn": "brc-FullClient",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "FullClient",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-CacheDB",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CacheDB",
#                                 "tRn": "brc-CacheDB",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CacheDB",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:22.505-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-CommProxy_BD",
#                                 "tRn": "BD-CommProxy_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "CommProxy_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-MyChart",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.786-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "MyChart",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "16402",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-MyChart",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-MyChart",
#                                 "tRn": "brc-MyChart",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "MyChart",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-CacheDB",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CacheDB",
#                                 "tRn": "brc-CacheDB",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CacheDB",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-Kulper",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-Kulper",
#                                 "tRn": "brc-Kulper",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "Kulper",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:23.412-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-MyChart_BD",
#                                 "tRn": "BD-MyChart_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "MyChart_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-IVR_Server",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.786-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "IVR_Server",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "16400",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-IVR_Server",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-IVR_Server",
#                                 "tRn": "brc-IVR_Server",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "IVR_Server",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-CacheDB",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CacheDB",
#                                 "tRn": "brc-CacheDB",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CacheDB",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:23.412-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-IVR_Server",
#                                 "tRn": "BD-IVR_Server",
#                                 "tType": "name",
#                                 "tnFvBDName": "IVR_Server",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-WarpDrive",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.786-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "WarpDrive",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "32785",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-WarpDrive",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-WarpDrive",
#                                 "tRn": "brc-WarpDrive",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "WarpDrive",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-HyperSpaceWeb",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-HyperSpaceWeb",
#                                 "tRn": "brc-HyperSpaceWeb",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "HyperSpaceWeb",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-CitrixFarm",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CitrixFarm",
#                                 "tRn": "brc-CitrixFarm",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CitrixFarm",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:22.505-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-WarpDrive_BD",
#                                 "tRn": "BD-WarpDrive_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "WarpDrive_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-WebBlob",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.412-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "WebBlob",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "32782",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-WebBlob",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-WebBlob",
#                                 "tRn": "brc-WebBlob",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "WebBlob",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
# ...
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-HyperSpaceWeb_BD",
#                                 "tRn": "BD-HyperSpaceWeb_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "HyperSpaceWeb_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "",
#                     "dn": "uni/tn-EPIC/ap-EPIC/epg-WinPrintServer",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-11-17T15:11:23.412-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "WinPrintServer",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "49165",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2818048",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "15564440312192464251",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-WinPrintServer",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-WinPrintServer",
#                                 "tRn": "brc-WinPrintServer",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "WinPrintServer",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-CitrixFarm",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-CitrixFarm",
#                                 "tRn": "brc-CitrixFarm",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "CitrixFarm",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.283-05:00",
#                                 "monPolDn": "",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-NetworkPrinter",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/brc-NetworkPrinter",
#                                 "tRn": "brc-NetworkPrinter",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "NetworkPrinter",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T16:12:56.036-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-11-17T15:11:22.505-05:00",
#                                 "monPolDn": "",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-EPIC/BD-WinPrintServer_BD",
#                                 "tRn": "BD-WinPrintServer_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "WinPrintServer_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         {
#             "fvAEPg": {
#                 "attributes": {
#                     "annotation": "",
#                     "childAction": "",
#                     "configIssues": "",
#                     "configSt": "applied",
#                     "descr": "",
#                     "dn": "uni/tn-andrew/ap-EPIC/epg-FileServers",
#                     "exceptionTag": "",
#                     "extMngdBy": "",
#                     "floodOnEncap": "disabled",
#                     "fwdCtrl": "",
#                     "hasMcastSource": "no",
#                     "isAttrBasedEPg": "no",
#                     "isSharedSrvMsiteEPg": "no",
#                     "lcOwn": "local",
#                     "matchT": "AtleastOne",
#                     "modTs": "2018-12-19T12:08:03.730-05:00",
#                     "monPolDn": "uni/tn-common/monepg-default",
#                     "name": "FileServers",
#                     "nameAlias": "",
#                     "pcEnfPref": "unenforced",
#                     "pcTag": "16408",
#                     "prefGrMemb": "exclude",
#                     "prio": "unspecified",
#                     "scope": "2260992",
#                     "shutdown": "no",
#                     "status": "",
#                     "triggerSt": "triggerable",
#                     "txId": "14411518807586565040",
#                     "uid": "15374"
#                 },
#                 "children": [
#                     {
#                         "fvRsProv": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "matchT": "AtleastOne",
#                                 "modTs": "2018-12-19T12:08:03.730-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rsprov-FileServer",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-andrew/brc-FileServer",
#                                 "tRn": "brc-FileServer",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "FileServer",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCons": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "ctrctUpd": "ctrct",
#                                 "deplInfo": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-12-19T12:08:03.730-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "prio": "unspecified",
#                                 "rType": "mo",
#                                 "rn": "rscons-WebBlob",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "vzBrCP",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-andrew/brc-WebBlob",
#                                 "tRn": "brc-WebBlob",
#                                 "tType": "name",
#                                 "tnVzBrCPName": "WebBlob",
#                                 "triggerSt": "triggerable",
#                                 "uid": "15374",
#                                 "updateCollection": "no"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsCustQosPol": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-12-19T12:08:02.847-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "rType": "mo",
#                                 "rn": "rscustQosPol",
#                                 "state": "formed",
#                                 "stateQual": "default-target",
#                                 "status": "",
#                                 "tCl": "qosCustomPol",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-common/qoscustom-default",
#                                 "tRn": "qoscustom-default",
#                                 "tType": "name",
#                                 "tnQosCustomPolName": "",
#                                 "uid": "0"
#                             }
#                         }
#                     },
#                     {
#                         "fvRsBd": {
#                             "attributes": {
#                                 "annotation": "",
#                                 "childAction": "",
#                                 "extMngdBy": "",
#                                 "forceResolve": "yes",
#                                 "lcOwn": "local",
#                                 "modTs": "2018-12-19T12:08:02.718-05:00",
#                                 "monPolDn": "uni/tn-common/monepg-default",
#                                 "rType": "mo",
#                                 "rn": "rsbd",
#                                 "state": "formed",
#                                 "stateQual": "none",
#                                 "status": "",
#                                 "tCl": "fvBD",
#                                 "tContextDn": "",
#                                 "tDn": "uni/tn-andrew/BD-FileServers_BD",
#                                 "tRn": "BD-FileServers_BD",
#                                 "tType": "name",
#                                 "tnFvBDName": "FileServers_BD",
#                                 "uid": "0"
#                             }
#                         }
#                     }
#                 ]
#             }
#         }
#     ],
#     "totalCount": "83"
# }

# %%
# Read the imdata key, and assign the value (a list of objects) to epg_objects_list.
epg_objects_list = epg_json['imdata']
epg_objects_list
# Out:
# [{'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': 'Digitial Signing Server',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-Digital_SS',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.786-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'Digital_SS',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '32784',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-DigitalSigningServer',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-DigitalSigningServer',
#        'tRn': 'brc-DigitalSigningServer',
#        'tType': 'name',
#        'tnVzBrCPName': 'DigitalSigningServer',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.505-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-Digital_SS_BD',
#        'tRn': 'BD-Digital_SS_BD',
#        'tType': 'name',
#        'tnFvBDName': 'Digital_SS_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': 'EPIC CareLink Web',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-CareLinkWeb',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.786-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'CareLinkWeb',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '49168',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-EpicCare_Link',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-EpicCare_Link',
#        'tRn': 'brc-EpicCare_Link',
#        'tType': 'name',
#        'tnVzBrCPName': 'EpicCare_Link',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.505-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-CareLinkWeb_BD',
#        'tRn': 'BD-CareLinkWeb_BD',
#        'tType': 'name',
#        'tnFvBDName': 'CareLinkWeb_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-CommProxy',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.412-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'CommProxy',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '32780',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-CommProxy',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CommProxy',
#        'tRn': 'brc-CommProxy',
#        'tType': 'name',
#        'tnVzBrCPName': 'CommProxy',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-FullClient',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-FullClient',
#        'tRn': 'brc-FullClient',
#        'tType': 'name',
#        'tnVzBrCPName': 'FullClient',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.505-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-CommProxy_BD',
#        'tRn': 'BD-CommProxy_BD',
#        'tType': 'name',
#        'tnFvBDName': 'CommProxy_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-MyChart',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.786-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'MyChart',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '16402',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-MyChart',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-MyChart',
#        'tRn': 'brc-MyChart',
#        'tType': 'name',
#        'tnVzBrCPName': 'MyChart',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-Kulper',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-Kulper',
#        'tRn': 'brc-Kulper',
#        'tType': 'name',
#        'tnVzBrCPName': 'Kulper',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:23.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-MyChart_BD',
#        'tRn': 'BD-MyChart_BD',
#        'tType': 'name',
#        'tnFvBDName': 'MyChart_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-IVR_Server',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.786-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'IVR_Server',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '16400',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-IVR_Server',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-IVR_Server',
#        'tRn': 'brc-IVR_Server',
#        'tType': 'name',
#        'tnVzBrCPName': 'IVR_Server',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:23.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-IVR_Server',
#        'tRn': 'BD-IVR_Server',
#        'tType': 'name',
#        'tnFvBDName': 'IVR_Server',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-WarpDrive',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.786-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'WarpDrive',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '32785',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-WarpDrive',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-WarpDrive',
#        'tRn': 'brc-WarpDrive',
#        'tType': 'name',
#        'tnVzBrCPName': 'WarpDrive',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-HyperSpaceWeb',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-HyperSpaceWeb',
#        'tRn': 'brc-HyperSpaceWeb',
#        'tType': 'name',
#        'tnVzBrCPName': 'HyperSpaceWeb',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CitrixFarm',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CitrixFarm',
#        'tRn': 'brc-CitrixFarm',
#        'tType': 'name',
#        'tnVzBrCPName': 'CitrixFarm',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.505-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-WarpDrive_BD',
#        'tRn': 'BD-WarpDrive_BD',
#        'tType': 'name',
#        'tnFvBDName': 'WarpDrive_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-WebBlob',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.412-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'WebBlob',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '32782',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-WebBlob',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-WebBlob',
#        'tRn': 'brc-WebBlob',
#        'tType': 'name',
#        'tnVzBrCPName': 'WebBlob',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-EpicPrintFormatServer',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-EpicPrintFormatServer',
#        'tRn': 'brc-EpicPrintFormatServer',
#        'tType': 'name',
#        'tnVzBrCPName': 'EpicPrintFormatServer',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CitrixFarm',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CitrixFarm',
#        'tRn': 'brc-CitrixFarm',
#        'tType': 'name',
#        'tnVzBrCPName': 'CitrixFarm',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-FileServer',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-FileServer',
#        'tRn': 'brc-FileServer',
#        'tType': 'name',
#        'tnVzBrCPName': 'FileServer',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-WillowAmbSQL',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-WillowAmbSQL',
#        'tRn': 'brc-WillowAmbSQL',
#        'tType': 'name',
#        'tnVzBrCPName': 'WillowAmbSQL',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.505-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-WebBlob_BD',
#        'tRn': 'BD-WebBlob_BD',
#        'tType': 'name',
#        'tnFvBDName': 'WebBlob_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC2/ap-EPIC/epg-CacheDB',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:22.310-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'CacheDB',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '32773',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2424833',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '16140901064495888032',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-SystemPulse',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/brc-SystemPulse',
#        'tRn': 'brc-SystemPulse',
#        'tType': 'name',
#        'tnVzBrCPName': 'SystemPulse',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CitrixFarm',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/brc-CitrixFarm',
#        'tRn': 'brc-CitrixFarm',
#        'tType': 'name',
#        'tnVzBrCPName': 'CitrixFarm',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-BCA_Relay',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/brc-BCA_Relay',
#        'tRn': 'brc-BCA_Relay',
#        'tType': 'name',
#        'tnVzBrCPName': 'BCA_Relay',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.310-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/BD-CacheDB_BD',
#        'tRn': 'BD-CacheDB_BD',
#        'tType': 'name',
#        'tnFvBDName': 'CacheDB_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': 'Clarity - Cogito - RDMS',
#     'dn': 'uni/tn-EPIC4/ap-EPIC/epg-Clarity',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-12-17T15:00:21.412-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'Clarity',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '49155',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '3080193',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '17293822569103895813',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-Clarity',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-Clarity',
#        'tRn': 'brc-Clarity',
#        'tType': 'name',
#        'tnVzBrCPName': 'Clarity',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-SQL',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-SQL',
#        'tRn': 'brc-SQL',
#        'tType': 'name',
#        'tnVzBrCPName': 'SQL',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-Printers',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-Printers',
#        'tRn': 'brc-Printers',
#        'tType': 'name',
#        'tnVzBrCPName': 'Printers',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:20.597-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:20.553-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/BD-Clarity_BD',
#        'tRn': 'BD-Clarity_BD',
#        'tType': 'name',
#        'tnFvBDName': 'Clarity_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': 'Hyperspace - Xendesktop',
#     'dn': 'uni/tn-EPIC4/ap-EPIC/epg-Presentation',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-12-17T15:00:21.412-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'Presentation',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '32770',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '3080193',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '17293822569103895813',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-HyperSpace',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-HyperSpace',
#        'tRn': 'brc-HyperSpace',
#        'tType': 'name',
#        'tnVzBrCPName': 'HyperSpace',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-WEB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-WEB',
#        'tRn': 'brc-WEB',
#        'tType': 'name',
#        'tnVzBrCPName': 'WEB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-MyChart',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-MyChart',
#        'tRn': 'brc-MyChart',
#        'tType': 'name',
#        'tnVzBrCPName': 'MyChart',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-XenApp',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-XenApp',
#        'tRn': 'brc-XenApp',
#        'tType': 'name',
#        'tnVzBrCPName': 'XenApp',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-BCA',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-BCA',
#        'tRn': 'brc-BCA',
#        'tType': 'name',
#        'tnVzBrCPName': 'BCA',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-SQL',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-SQL',
#        'tRn': 'brc-SQL',
#        'tType': 'name',
#        'tnVzBrCPName': 'SQL',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-Printers',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-Printers',
#        'tRn': 'brc-Printers',
#        'tType': 'name',
#        'tnVzBrCPName': 'Printers',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-Kuiper',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-Kuiper',
#        'tRn': 'brc-Kuiper',
#        'tType': 'name',
#        'tnVzBrCPName': 'Kuiper',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-Clarity',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-Clarity',
#        'tRn': 'brc-Clarity',
#        'tType': 'name',
#        'tnVzBrCPName': 'Clarity',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:21.412-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC4/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-17T15:00:20.597-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
# ...
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-MultiPurposeSQL',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/brc-MultiPurposeSQL',
#        'tRn': 'brc-MultiPurposeSQL',
#        'tType': 'name',
#        'tnVzBrCPName': 'MultiPurposeSQL',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-NetworkPrinter',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/brc-NetworkPrinter',
#        'tRn': 'brc-NetworkPrinter',
#        'tType': 'name',
#        'tnVzBrCPName': 'NetworkPrinter',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:55.604-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.310-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC2/BD-Clarity_BD',
#        'tRn': 'BD-Clarity_BD',
#        'tType': 'name',
#        'tnFvBDName': 'Clarity_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-HyperSpaceWeb',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.412-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'HyperSpaceWeb',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '32788',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-HyperSpaceWeb',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-HyperSpaceWeb',
#        'tRn': 'brc-HyperSpaceWeb',
#        'tType': 'name',
#        'tnVzBrCPName': 'HyperSpaceWeb',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CitrixFarm',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CitrixFarm',
#        'tRn': 'brc-CitrixFarm',
#        'tType': 'name',
#        'tnVzBrCPName': 'CitrixFarm',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CacheDB',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CacheDB',
#        'tRn': 'brc-CacheDB',
#        'tType': 'name',
#        'tnVzBrCPName': 'CacheDB',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-WarpDrive',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-WarpDrive',
#        'tRn': 'brc-WarpDrive',
#        'tType': 'name',
#        'tnVzBrCPName': 'WarpDrive',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.505-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-HyperSpaceWeb_BD',
#        'tRn': 'BD-HyperSpaceWeb_BD',
#        'tType': 'name',
#        'tnFvBDName': 'HyperSpaceWeb_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-EPIC/ap-EPIC/epg-WinPrintServer',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-11-17T15:11:23.412-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'WinPrintServer',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '49165',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2818048',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '15564440312192464251',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-WinPrintServer',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-WinPrintServer',
#        'tRn': 'brc-WinPrintServer',
#        'tType': 'name',
#        'tnVzBrCPName': 'WinPrintServer',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-CitrixFarm',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-CitrixFarm',
#        'tRn': 'brc-CitrixFarm',
#        'tType': 'name',
#        'tnVzBrCPName': 'CitrixFarm',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.283-05:00',
#        'monPolDn': '',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-NetworkPrinter',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/brc-NetworkPrinter',
#        'tRn': 'brc-NetworkPrinter',
#        'tType': 'name',
#        'tnVzBrCPName': 'NetworkPrinter',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T16:12:56.036-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-11-17T15:11:22.505-05:00',
#        'monPolDn': '',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-EPIC/BD-WinPrintServer_BD',
#        'tRn': 'BD-WinPrintServer_BD',
#        'tType': 'name',
#        'tnFvBDName': 'WinPrintServer_BD',
#        'uid': '0'}}}]}},
#  {'fvAEPg': {'attributes': {'annotation': '',
#     'childAction': '',
#     'configIssues': '',
#     'configSt': 'applied',
#     'descr': '',
#     'dn': 'uni/tn-andrew/ap-EPIC/epg-FileServers',
#     'exceptionTag': '',
#     'extMngdBy': '',
#     'floodOnEncap': 'disabled',
#     'fwdCtrl': '',
#     'hasMcastSource': 'no',
#     'isAttrBasedEPg': 'no',
#     'isSharedSrvMsiteEPg': 'no',
#     'lcOwn': 'local',
#     'matchT': 'AtleastOne',
#     'modTs': '2018-12-19T12:08:03.730-05:00',
#     'monPolDn': 'uni/tn-common/monepg-default',
#     'name': 'FileServers',
#     'nameAlias': '',
#     'pcEnfPref': 'unenforced',
#     'pcTag': '16408',
#     'prefGrMemb': 'exclude',
#     'prio': 'unspecified',
#     'scope': '2260992',
#     'shutdown': 'no',
#     'status': '',
#     'triggerSt': 'triggerable',
#     'txId': '14411518807586565040',
#     'uid': '15374'},
#    'children': [{'fvRsProv': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'matchT': 'AtleastOne',
#        'modTs': '2018-12-19T12:08:03.730-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rsprov-FileServer',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-andrew/brc-FileServer',
#        'tRn': 'brc-FileServer',
#        'tType': 'name',
#        'tnVzBrCPName': 'FileServer',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCons': {'attributes': {'annotation': '',
#        'childAction': '',
#        'ctrctUpd': 'ctrct',
#        'deplInfo': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-19T12:08:03.730-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'prio': 'unspecified',
#        'rType': 'mo',
#        'rn': 'rscons-WebBlob',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'vzBrCP',
#        'tContextDn': '',
#        'tDn': 'uni/tn-andrew/brc-WebBlob',
#        'tRn': 'brc-WebBlob',
#        'tType': 'name',
#        'tnVzBrCPName': 'WebBlob',
#        'triggerSt': 'triggerable',
#        'uid': '15374',
#        'updateCollection': 'no'}}},
#     {'fvRsCustQosPol': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-19T12:08:02.847-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rscustQosPol',
#        'state': 'formed',
#        'stateQual': 'default-target',
#        'status': '',
#        'tCl': 'qosCustomPol',
#        'tContextDn': '',
#        'tDn': 'uni/tn-common/qoscustom-default',
#        'tRn': 'qoscustom-default',
#        'tType': 'name',
#        'tnQosCustomPolName': '',
#        'uid': '0'}}},
#     {'fvRsBd': {'attributes': {'annotation': '',
#        'childAction': '',
#        'extMngdBy': '',
#        'forceResolve': 'yes',
#        'lcOwn': 'local',
#        'modTs': '2018-12-19T12:08:02.718-05:00',
#        'monPolDn': 'uni/tn-common/monepg-default',
#        'rType': 'mo',
#        'rn': 'rsbd',
#        'state': 'formed',
#        'stateQual': 'none',
#        'status': '',
#        'tCl': 'fvBD',
#        'tContextDn': '',
#        'tDn': 'uni/tn-andrew/BD-FileServers_BD',
#        'tRn': 'BD-FileServers_BD',
#        'tType': 'name',
#        'tnFvBDName': 'FileServers_BD',
#        'uid': '0'}}}]}}]

# %%
#Set up some empty lists to capture the data we need. 
tenant_list = []
ap_list = []
epg_list = []
endpoint_list = []
ip_list = []
mac_list = []
encap_list = []

# %%
# Now we have a list of objects, let's iterate over each object and do the following:
#  - Grab the Distriguished name (DN)
#  - Split the DN string into a list using the forward slash as a separator
#  - Ignore uni, which is element 0.
#  - Then, grab the tenant from element 1
#  - the Application profile (AP) is element 2
#  - Skip to the last element (-1) to grab the endpoint group.
#  - In the aci-get-global-endpoints example, we describe why we read from the end.
#  - But basically, the last element is always endpoint, but the fourth (3) element is not always
#    the last element.

for epg_object in epg_objects_list:
    #print(object)
    dn = epg_object['fvAEPg']['attributes']['dn']
    #print(child)
    #print(dn)
    split_dn = dn.split("/")
    tenant = split_dn[1]
    ap = split_dn[2]
    epg = split_dn[-1]
    
    # Get the child objects, which are values under the key "children".
    # We also set null value for endpoint, ip address, mac, and encapsulation.
    # Not every EPG will have and endpoint, so we want to keep a placeholder.
    
    children_list = epg_object['fvAEPg']['children']
    endpoint = None
    ip = None
    mac = None
    encap = None
    for child in children_list:
        #print(child.items())
        
        # For each child object, we look for anything in the class "fvCEp", which is an endpoint.
        # If it is, we overwrite the null values for endpoint name, ip, mac, and encapsulation.
        # If it isn't fvCEp, we skip it and just keep the placeholders above.
        # Uncomment the print statements if you want to see the data.
        if "fvCEp" in child:
            endpoint = child['fvCEp']['attributes']['name']
            ip = child['fvCEp']['attributes']['ip']
            mac = child['fvCEp']['attributes']['mac']
            encap = child['fvCEp']['attributes']['encap']
    #print(tenant, ap, epg, endpoint, ip, mac, encap)
    # Append our extracted values into each of the lists we created above.
    tenant_list.append(tenant)
    ap_list.append(ap)
    epg_list.append(epg)
    endpoint_list.append(endpoint)
    ip_list.append(ip)
    mac_list.append(mac)
    encap_list.append(encap)

# %%
# Zip the lists into a zip object. This effectively turns then into tuples of 
# tenant, application profile, EPG, endpoint, etc.
tn_ep_list = zip(tenant_list, ap_list, epg_list, endpoint_list, ip_list, mac_list, encap_list)

# %%
# Take the zip of tuples, convert to list, and stuff them into a Pandas dataframe.
# Also, convert "None" to numpy NaN, though Pandas deals with "None" just fine for groupby objects. 
df_input = list(tn_ep_list)
df = pd.DataFrame(df_input, columns=("Tenant","AP","EPG","Endpoint","IP","MAC Addy","Encap"))
df.fillna(value=pd.np.nan, inplace=True)

# %%
# Sort dataframe by Endpoints and then print the first 20 rows
df.sort_values(by=['Endpoint'], ascending=False).head(20)

# Or sort dataframe by Endpoints and then print it all.
#df.sort_values(by=['Endpoint'], ascending=False)

# Or you can just print the dataframe:
# df
# Out:
#        Tenant            AP               EPG           Endpoint           IP  \
# 18   tn-COAST       ap-app1         epg-epg1b  00:50:56:93:6C:74  101.1.1.102
# 0     tn-EPIC       ap-EPIC    epg-Digital_SS                NaN          NaN
# 1     tn-EPIC       ap-EPIC   epg-CareLinkWeb                NaN          NaN
# 2     tn-EPIC       ap-EPIC     epg-CommProxy                NaN          NaN
# 3     tn-EPIC       ap-EPIC       epg-MyChart                NaN          NaN
# 4     tn-EPIC       ap-EPIC    epg-IVR_Server                NaN          NaN
# 5     tn-EPIC       ap-EPIC     epg-WarpDrive                NaN          NaN
# 6     tn-EPIC       ap-EPIC       epg-WebBlob                NaN          NaN
# 7    tn-EPIC2       ap-EPIC       epg-CacheDB                NaN          NaN
# 8    tn-EPIC4       ap-EPIC       epg-Clarity                NaN          NaN
# 9    tn-EPIC4       ap-EPIC  epg-Presentation                NaN          NaN
# 10   tn-EPIC4       ap-EPIC       epg-CacheDB                NaN          NaN
# 11   tn-EPIC4       ap-EPIC  epg-MultiPurpose                NaN          NaN
# 12   tn-EPIC4       ap-EPIC  epg-ClientAccess                NaN          NaN
# 13   tn-COAST       ap-mgmt          epg-dhcp                NaN          NaN
# 14   tn-COAST       ap-app1          epg-epg1                NaN          NaN
# 15   tn-COAST       ap-app1          epg-epg3                NaN          NaN
# 16   tn-COAST       ap-app1          epg-epg2                NaN          NaN
# 17   tn-COAST  ap-BOOMER_AP    epg-BOOMER_EPG                NaN          NaN
# 19  tn-andrew       ap-EPIC     epg-CommProxy                NaN          NaN
#
#              MAC Addy      Encap
# 18  00:50:56:93:6C:74  vlan-1102
# 0                 NaN        NaN
# 1                 NaN        NaN
# 2                 NaN        NaN
# 3                 NaN        NaN
# 4                 NaN        NaN
# 5                 NaN        NaN
# 6                 NaN        NaN
# 7                 NaN        NaN
# 8                 NaN        NaN
# 9                 NaN        NaN
# 10                NaN        NaN
# 11                NaN        NaN
# 12                NaN        NaN
# 13                NaN        NaN
# 14                NaN        NaN
# 15                NaN        NaN
# 16                NaN        NaN
# 17                NaN        NaN
# 19                NaN        NaN

# %%
# Report total number of EPGs and EPs per Tenant using groupby object.
grouped_df = df.groupby(['Tenant']).agg({'EPG':'count','Endpoint':'count'})
grouped_df
# Out:
#               EPG  Endpoint
# Tenant
# tn-COAST        6         1
# tn-EPIC        28         0
# tn-EPIC2        5         0
# tn-EPIC3        5         0
# tn-EPIC4        5         0
# tn-JW_Tenant    1         0
# tn-J_Tenant     3         0
# tn-andrew      28         0
# tn-infra        2         0

# %%
# We can drop all rows with any empty fields.
df = df.dropna()

# %%
df
# Out:
#       Tenant       AP        EPG           Endpoint           IP  \
# 18  tn-COAST  ap-app1  epg-epg1b  00:50:56:93:6C:74  101.1.1.102
#
#              MAC Addy      Encap
# 18  00:50:56:93:6C:74  vlan-1102
