# %% [markdown]
# # Ops Check
# ## A Python script to gather data on the ACI fabric's operational state.

# %% [markdown]
# Overview:
# The script will carry out API calls necessary to gather important info-at-a-glance, then print to console/display.
#
# Flow:
# 1. Authenticate with config.py or interactively.
# 2. Gather:
#    - Fabric Health Score
#    - Faults
#    - Global Endpoints
#    - Tenant Endpoints by EPG
# 3. Display summary report.
# 4. Display full report.

# %%
# Import needed modules
import requests
import json
import pandas as pd
import os
import sys

# %%
# Grab credentials from config.py file in same directory.
# TO DO: Test variables, and prompt for interactive entry if empty.
from config import controller, username, password

# %%
# Set some variables to construct our login URLs
base_url = "https://" + str(controller) + "/api/"
auth_bit = "aaaLogin.json"

auth_url = base_url + auth_bit
#auth_url

# %%
# JSON data constructed from user/pass above.
auth_data = {
  "aaaUser":{
    "attributes":{
      "name":username,
      "pwd":password
    }
  }
}

# %%
# Comment or delete this line if you want to see SSL certificate warnings (eg, self-signed, untrusted, etc)
requests.packages.urllib3.disable_warnings()

# %%
# Initiate a session with the APIC
s = requests.session()
s.post(auth_url, json=auth_data, verify=False)
# Out:
# <Response [200]>

# %%
# Set up our class/object URI variables
# Global Endpoints Class
global_ep="node/class/fvCEp.json"

# Tenant Endpoints by EPG
tenant_endpoints = "node/class/fvAEPg.json"
c_string = "?rsp-subtree=children"
tenant_endpoints_url = base_url + tenant_endpoints + c_string


# Health Score / Summary Classes
health = "node/mo/topology/HDfabricOverallHealth5min-0.json"
info = "node/mo/info.json"
fault = "node/class/faultSummary.json"

global_ep_url = base_url + global_ep
health_url = base_url + health
info_url = base_url + info
fault_url = base_url + fault

# Set up the URLs to query.
qstring = "?rsp-subtree=children"
# Construct the user post URL
fabric_object="node/mo/uni/fabric.json"
fabric_url = base_url + fabric_object + qstring

# %%
def get_endpoints(url):
    s_response = s.get(url, verify=False)
    s_global_ep = s_response.json()
    tenant_list = []
    epg_list = []
    ep_list = []
    ip_list = []
    mac_list = []
    encap_list = []

    object_list = s_global_ep['imdata']
    for object in object_list:
        #print(object)
        dn = object['fvCEp']['attributes']['dn']
        split_dn = dn.split("/")
        tenant_list.append(split_dn[1])
        epg_list.append(split_dn[-2])
        ep_list.append(split_dn[-1])
        ip_list.append(object['fvCEp']['attributes']['ip'])
        mac_list.append(object['fvCEp']['attributes']['mac'])
        encap_list.append(object['fvCEp']['attributes']['encap'])
    list_of_global_ep = zip(tenant_list, epg_list, ep_list, ip_list, mac_list, encap_list)
    df_input = list(list_of_global_ep)
    df = pd.DataFrame(df_input, columns=("Tenant","EPG or VRF/L3out","Endpoint","IP","MAC Addy","Encap"))
    ep = df[['Tenant','Endpoint']]
    grouped_df = ep.groupby(['Tenant']).count()
    return grouped_df, df

# %%
# Get Global Endpoints 
global_endpoints_summary, global_endpoints = get_endpoints(global_ep_url)

# %%
def get_tenant_endpoints(url):
    epg_response = s.get(tenant_endpoints_url, verify=False)
    epg_json = epg_response.json()
    epg_objects_list = epg_json['imdata']
    tenant_list = []
    ap_list = []
    epg_list = []
    endpoint_list = []
    ip_list = []
    mac_list = []
    encap_list = []
    for epg_object in epg_objects_list:
        dn = epg_object['fvAEPg']['attributes']['dn']
        split_dn = dn.split("/")
        tenant = split_dn[1]
        ap = split_dn[2]
        epg = split_dn[-1]
        children_list = epg_object['fvAEPg']['children']
        endpoint = None
        ip = None
        mac = None
        encap = None
        for child in children_list:
            if "fvCEp" in child:
                endpoint = child['fvCEp']['attributes']['name']
                ip = child['fvCEp']['attributes']['ip']
                mac = child['fvCEp']['attributes']['mac']
                encap = child['fvCEp']['attributes']['encap']
        tenant_list.append(tenant)
        ap_list.append(ap)
        epg_list.append(epg)
        endpoint_list.append(endpoint)
        ip_list.append(ip)
        mac_list.append(mac)
        encap_list.append(encap)
    tn_ep_list = zip(tenant_list, ap_list, epg_list, endpoint_list, ip_list, mac_list, encap_list)
    df_input = list(tn_ep_list)
    df = pd.DataFrame(df_input, columns=("Tenant","AP","EPG","Endpoint","IP","MAC Addy","Encap"))
    df.fillna(value=pd.np.nan, inplace=True)
    sorted_df = df.sort_values(by=['Endpoint'], ascending=False)
    grouped_df = df.groupby(['Tenant']).agg({'EPG':'count','Endpoint':'count'})
    return grouped_df, sorted_df

# %%
# Get Endpoints summary by tenant, thenget list of all tenant endpoints, 
# including EPGs with no endpoints. 
tenant_endpoints_summary, tenant_endpoints = get_tenant_endpoints(tenant_endpoints_url)

# %%
# Returns Five Minute Health Score, Summary of Faults, and Table of Faults
def get_healthcheck(health_url, fault_url):
    # get ACI Fabric Health Score, Five Minute Average
    s_response = s.get(health_url, verify=False)
    s_health_data = s_response.json()
    health_score = s_health_data['imdata'][0]
    five_min_avg = health_score['fabricOverallHealthHist5min']['attributes']['healthAvg']
    # Get ACI faults
    s_response = s.get(fault_url, verify=False)
    s_fault = s_response.json()
    descr_list = []
    severity_list = []
    code_list = []
    type_list = []
    dn_list = []
    cause_list = []
    object_list = s_fault['imdata']
    for object in object_list:
        #print(object)
        dn_list.append(object['faultSummary']['attributes']['dn'])
        descr_list.append(object['faultSummary']['attributes']['descr'])
        severity_list.append(object['faultSummary']['attributes']['severity'])
        code_list.append(object['faultSummary']['attributes']['code'])
        type_list.append(object['faultSummary']['attributes']['type'])
        cause_list.append(object['faultSummary']['attributes']['cause'])
    list_of_objects = zip(code_list,severity_list,descr_list,cause_list,type_list,dn_list)
    df_input = list(list_of_objects)
    df = pd.DataFrame(df_input, columns=("Code","Severity","Description","Cause","Type","DN"))
    summary_df = df.groupby(['Severity', 'Type']).agg({'Cause':'count'})
    return five_min_avg, summary_df, df

# %%
score, fault_summary, fault_list = get_healthcheck(health_url, fault_url)

# %%
# Summary Output
print("ACI Operations Summary")
print("==================================================")
print(" ")
print("Health Score: " + str(score))
print(" ")
print("===== Faults =====")
print(fault_summary)
print(" ")
print("===== Global Endpoints =====")
print(global_endpoints_summary)
print(" ")
print("===== Tenant Endpoints =====")
print(tenant_endpoints_summary)
# Out:
# ACI Operations Summary
# ==================================================
#
# Health Score: 95
#
# ===== Faults =====
#                          Cause
# Severity Type
# major    communications      1
#          config              1
#          operational         3
# minor    config              4
#          environmental       1
#          operational         1
# warning  communications      2
#          config              8
#          operational         1
#
# ===== Global Endpoints =====
#                   Endpoint
# Tenant
# tn-APACHE-common         1
# tn-common                1
#
# ===== Tenant Endpoints =====
#                   EPG  Endpoint
# Tenant
# tn-APACHE-common    1         1
# tn-COAST            6         0
# tn-EPIC            28         0
# tn-EPIC2            5         0
# tn-EPIC3            5         0
# tn-EPIC4            5         0
# tn-JW_Tenant        1         0
# tn-J_Tenant         3         0
# tn-andrew          28         0
# tn-infra            2         0

# %%
i = input("[C]ontinue with Full Report, or [Q]uit?")
if i == "q" or i == "Q":
    sys.exit()
# Out:
# [C]ontinue with Full Report, or [Q]uit?C

# %%
# Full Output
print("ACI Operations Report")
print("==================================================")
print(" ")
print("Health Score: " + str(score))
print(" ")
print("===== Faults =====")
print(fault_list)
print(" ")
print("===== Global Endpoints =====")
print(global_endpoints)
print(" ")
print("===== Tenant Endpoints =====")
print(tenant_endpoints)
# Out:
# ACI Operations Report
# ==================================================
#
# Health Score: 95
#
# ===== Faults =====
#      Code Severity                                        Description  \
# 0   F1123  warning  The object refers to an object that was not fo...
# 1   F2111  warning  The object refers to an object that was not fo...
# 2   F1003  warning  The object refers to an object that was not fo...
# 3   F0981  warning  The object refers to an object that was not fo...
# 4   F0053    minor  This fault occurs when a configuration export/...
# 5   F0467    minor  This fault occurs when an End Point Group is i...
# 6   F0546  warning            This fault occurs when a port goes down
# 7   F1296    major  This fault occurs when vpc interface goes down...
# 8   F1480    major  This fault occurs when a software upgrade fail...
# 9   F0103    major  This fault occurs when a physical interface on...
# 10  F2740  warning  This fault occurs when port speed is configure...
# 11  F3062    major  This fault is raised when product license eval...
# 12  F3057  warning  This fault is raised when APIC Controller prod...
# 13  F0887  warning  The object refers to an object that was not fo...
# 14  F2543    major    This fault is raised when there are DHCP issues
# 15  F0956  warning  The object refers to an object that was not fo...
# 16  F1040  warning  The object refers to an object that was not fo...
# 17  F2650    minor                        Plugin has failed to start.
# 18  F0756    minor  This fault occurs when a configured target of ...
# 19  F1298    minor  : This fault occurs when deliverying EPg polic...
# 20  F1527  warning  This fault occurs when the utilization of stor...
# 21  F0413    minor      This fault occurs when the the psu is missing
#
#                             Cause            Type             DN
# 0               resolution-failed          config  fltcode-F1123
# 1               resolution-failed          config  fltcode-F2111
# 2               resolution-failed          config  fltcode-F1003
# 3               resolution-failed          config  fltcode-F0981
# 4            configuration-failed          config  fltcode-F0053
# 5            configuration-failed          config  fltcode-F0467
# 6         interface-physical-down  communications  fltcode-F0546
# 7              interface-vpc-down  communications  fltcode-F1296
# 8                  upgrade-failed     operational  fltcode-F1480
# 9                       port-down     operational  fltcode-F0103
# 10  invalid-port-speed-configured  communications  fltcode-F2740
# 11      evaluation-period-expired          config  fltcode-F3062
# 12         product-not-registered          config  fltcode-F3057
# 13              resolution-failed          config  fltcode-F0887
# 14          invalid-configuration     operational  fltcode-F2543
# 15              resolution-failed          config  fltcode-F0956
# 16              resolution-failed          config  fltcode-F1040
# 17                failed-to-start     operational  fltcode-F2650
# 18              resolution-failed          config  fltcode-F0756
# 19           configuration-failed          config  fltcode-F1298
# 20                 equipment-full     operational  fltcode-F1527
# 21          equipment-psu-missing   environmental  fltcode-F0413
#
# ===== Global Endpoints =====
#              Tenant EPG or VRF/L3out               Endpoint        IP  \
# 0         tn-common      ctx-default  cep-00:DE:FB:79:8B:C3  10.2.1.5
# 1  tn-APACHE-common   epg-Brahmatron  cep-00:50:56:93:6C:74   0.0.0.0
#
#             MAC Addy      Encap
# 0  00:DE:FB:79:8B:C3   vlan-240
# 1  00:50:56:93:6C:74  vlan-1369
#
# ===== Tenant Endpoints =====
#               Tenant               AP                    EPG  \
# 19  tn-APACHE-common            ap-AP         epg-Brahmatron
# 0            tn-EPIC          ap-EPIC         epg-Digital_SS
# 1            tn-EPIC          ap-EPIC        epg-CareLinkWeb
# 2            tn-EPIC          ap-EPIC          epg-CommProxy
# 3            tn-EPIC          ap-EPIC            epg-MyChart
# 4            tn-EPIC          ap-EPIC         epg-IVR_Server
# 5            tn-EPIC          ap-EPIC          epg-WarpDrive
# 6            tn-EPIC          ap-EPIC            epg-WebBlob
# 7           tn-EPIC2          ap-EPIC            epg-CacheDB
# 8           tn-EPIC4          ap-EPIC            epg-Clarity
# 9           tn-EPIC4          ap-EPIC       epg-Presentation
# 10          tn-EPIC4          ap-EPIC            epg-CacheDB
# 11          tn-EPIC4          ap-EPIC       epg-MultiPurpose
# 12          tn-EPIC4          ap-EPIC       epg-ClientAccess
# 13          tn-COAST          ap-mgmt               epg-dhcp
# 14          tn-COAST     ap-BOOMER_AP         epg-BOOMER_EPG
# 15          tn-COAST          ap-app1              epg-epg1b
# 16          tn-COAST          ap-app1               epg-epg1
# 17          tn-COAST          ap-app1               epg-epg2
# 18          tn-COAST          ap-app1               epg-epg3
# 20         tn-andrew          ap-EPIC          epg-CommProxy
# 21         tn-andrew          ap-EPIC            epg-CacheDB
# 22         tn-andrew          ap-EPIC     epg-WinPrintServer
# 23         tn-andrew          ap-EPIC    epg-EPS_PrintServer
# 24         tn-andrew          ap-EPIC        epg-CareLinkWeb
# 25           tn-EPIC          ap-EPIC    epg-BusinessObjects
# 26          tn-infra      ap-ave-ctrl           epg-ave-ctrl
# 27         tn-andrew          ap-EPIC           epg-EpicThin
# 28         tn-andrew          ap-EPIC         epg-Digital_SS
# 29          tn-EPIC3          ap-EPIC            epg-Clarity
# ..               ...              ...                    ...
# 54       tn-J_Tenant  ap-AppProf_John             epg-Group3
# 55          tn-EPIC3          ap-EPIC       epg-MultiPurpose
# 56         tn-andrew          ap-EPIC          epg-EpicThick
# 57           tn-EPIC          ap-EPIC             epg-Kulper
# 58         tn-andrew          ap-EPIC          epg-WarpDrive
# 59          tn-EPIC3          ap-EPIC            epg-CacheDB
# 60         tn-andrew          ap-EPIC       epg-CitrixXenApp
# 61         tn-andrew          ap-EPIC  epg-IC_CareEverywhere
# 62           tn-EPIC          ap-EPIC    epg-NetworkPrinters
# 63           tn-EPIC          ap-EPIC          epg-EpicThick
# 64       tn-J_Tenant  ap-AppProf_John             epg-Group1
# 65       tn-J_Tenant  ap-AppProf_John             epg-Group2
# 66           tn-EPIC          ap-EPIC        epg-FileServers
# 67           tn-EPIC          ap-EPIC            epg-CacheDB
# 68      tn-JW_Tenant     ap-JW_App_AP         epg-JW_Web_EPG
# 69           tn-EPIC          ap-EPIC           epg-EpicThin
# 70           tn-EPIC          ap-EPIC                epg-SQL
# 71           tn-EPIC          ap-EPIC    epg-EPS_PrintServer
# 72           tn-EPIC          ap-EPIC  epg-IC_CareEverywhere
# 73           tn-EPIC          ap-EPIC        epg-ARR_Servers
# 74           tn-EPIC          ap-EPIC            epg-Clarity
# 75           tn-EPIC          ap-EPIC   epg-WillowAmbulatory
# 76           tn-EPIC          ap-EPIC          epg-BCA_Relay
# 77           tn-EPIC          ap-EPIC       epg-CitrixXenApp
# 78           tn-EPIC          ap-EPIC                epg-ICC
# 79           tn-EPIC          ap-EPIC        epg-SystemPulse
# 80          tn-EPIC2          ap-EPIC            epg-Clarity
# 81           tn-EPIC          ap-EPIC      epg-HyperSpaceWeb
# 82           tn-EPIC          ap-EPIC     epg-WinPrintServer
# 83         tn-andrew          ap-EPIC        epg-FileServers
#
#              Endpoint       IP           MAC Addy      Encap
# 19  00:50:56:93:6C:74  0.0.0.0  00:50:56:93:6C:74  vlan-1369
# 0                 NaN      NaN                NaN        NaN
# 1                 NaN      NaN                NaN        NaN
# 2                 NaN      NaN                NaN        NaN
# 3                 NaN      NaN                NaN        NaN
# 4                 NaN      NaN                NaN        NaN
# 5                 NaN      NaN                NaN        NaN
# 6                 NaN      NaN                NaN        NaN
# 7                 NaN      NaN                NaN        NaN
# 8                 NaN      NaN                NaN        NaN
# 9                 NaN      NaN                NaN        NaN
# 10                NaN      NaN                NaN        NaN
# 11                NaN      NaN                NaN        NaN
# 12                NaN      NaN                NaN        NaN
# 13                NaN      NaN                NaN        NaN
# 14                NaN      NaN                NaN        NaN
# 15                NaN      NaN                NaN        NaN
# 16                NaN      NaN                NaN        NaN
# 17                NaN      NaN                NaN        NaN
# 18                NaN      NaN                NaN        NaN
# 20                NaN      NaN                NaN        NaN
# 21                NaN      NaN                NaN        NaN
# 22                NaN      NaN                NaN        NaN
# 23                NaN      NaN                NaN        NaN
# 24                NaN      NaN                NaN        NaN
# 25                NaN      NaN                NaN        NaN
# 26                NaN      NaN                NaN        NaN
# 27                NaN      NaN                NaN        NaN
# 28                NaN      NaN                NaN        NaN
# 29                NaN      NaN                NaN        NaN
# ..                ...      ...                ...        ...
# 54                NaN      NaN                NaN        NaN
# 55                NaN      NaN                NaN        NaN
# 56                NaN      NaN                NaN        NaN
# 57                NaN      NaN                NaN        NaN
# 58                NaN      NaN                NaN        NaN
# 59                NaN      NaN                NaN        NaN
# 60                NaN      NaN                NaN        NaN
# 61                NaN      NaN                NaN        NaN
# 62                NaN      NaN                NaN        NaN
# 63                NaN      NaN                NaN        NaN
# 64                NaN      NaN                NaN        NaN
# 65                NaN      NaN                NaN        NaN
# 66                NaN      NaN                NaN        NaN
# 67                NaN      NaN                NaN        NaN
# 68                NaN      NaN                NaN        NaN
# 69                NaN      NaN                NaN        NaN
# 70                NaN      NaN                NaN        NaN
# 71                NaN      NaN                NaN        NaN
# 72                NaN      NaN                NaN        NaN
# 73                NaN      NaN                NaN        NaN
# 74                NaN      NaN                NaN        NaN
# 75                NaN      NaN                NaN        NaN
# 76                NaN      NaN                NaN        NaN
# 77                NaN      NaN                NaN        NaN
# 78                NaN      NaN                NaN        NaN
# 79                NaN      NaN                NaN        NaN
# 80                NaN      NaN                NaN        NaN
# 81                NaN      NaN                NaN        NaN
# 82                NaN      NaN                NaN        NaN
# 83                NaN      NaN                NaN        NaN
#
# [84 rows x 7 columns]
